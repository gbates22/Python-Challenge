# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Reference the file where the CSV is located
zillow_csv = 'price.csv'
zip_csv = 'RDC_InventoryCoreMetrics_Zip_Hist (1).csv'

# Import the data into a Pandas DataFrame
price_df = pd.read_csv(zillow_csv)
zip_csv = pd.read_csv(zip_csv)
price_df.head()
zip_csv.head()
# Out:
# C:\Users\Bates\Anaconda3\envs\PythonData\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Month  ZipCode          ZipName Footnote  Median Listing Price  \
# 0  2017-09-01   1001.0       Agawam, MA      NaN              213700.0
# 1  2017-09-01   1002.0      Amherst, MA      NaN              358500.0
# 2  2017-09-01   1005.0        Barre, MA      NaN              251300.0
# 3  2017-09-01   1007.0  Belchertown, MA      NaN              333600.0
# 4  2017-09-01   1008.0    Blandford, MA      NaN              186200.0
#
#    Median Listing Price M/M  Median Listing Price Y/Y  Active Listing Count   \
# 0                   -0.0387                   -0.0286                   52.0
# 1                   -0.0465                    0.0913                  110.0
# ...

# %%
price_df = price_df.loc[price_df['City Code']==24043]

price_2012df = price_df[['City Code','January 2012','February 2012','March 2012', 'April 2012','May 2012', 
          'June 2012', 'July 2012', 'August 2012','September 2012', 'October 2012', 'November 2012','December 2012']]

price_2012df1= price_df[['January 2012','February 2012','March 2012', 'April 2012','May 2012', 
          'June 2012', 'July 2012', 'August 2012','September 2012', 'October 2012', 'November 2012','December 2012']]
price_df
# Out:
#     City Code       City      Metro       County State  Population Rank  \
# 19      24043  Charlotte  Charlotte  Mecklenburg    NC               20
#
#     November 2010  December 2010  January 2011  February 2011      ...       \
# 19         1024.0         1022.0        1024.0         1026.0      ...
#
#     April 2016  May 2016  June 2016  July 2016  August 2016  September 2016  \
# 19        1276      1283       1289       1289         1287            1285
#
#     October 2016  November 2016  December 2016  January 2017
# 19          1285           1286           1290          1294
#
# [1 rows x 81 columns]

# %%
months_list =['January 2012','February 2012','March 2012', 'April 2012','May 2012', 
          'June 2012', 'July 2012', 'August 2012','September 2012', 'October 2012', 'November 2012','December 2012']

months= []
for month in months_list:
    months.append(month)
print(months_list) 
x_axis= months_list

#tick_locations=[value for value in x_axis]

price_2012df=price_2012df.T
price_2012df1=price_2012df1.T

price_2012df= price_2012df.rename(columns= { 19:'CharlotteRent_2012'})
price_2012df1= price_2012df1.rename(columns= { 19:'CharlotteRent_2012'})
# price_2012df= pd.to_numeric(price_2012df['CharlotteRent_2012'])

rent_costs= []
for value in (price_2012df1['CharlotteRent_2012']):
     rent_costs.append(value)
print(rent_costs)

# price_2012df['Rent_Cost_2012'] = price_2012df['Rent_Cost_2012'].map('${:.2f}'.format)
# Out:
# ['January 2012', 'February 2012', 'March 2012', 'April 2012', 'May 2012', 'June 2012', 'July 2012', 'August 2012', 'September 2012', 'October 2012', 'November 2012', 'December 2012']
# [1086.0, 1093.0, 1100.0, 1104.0, 1105.0, 1107.0, 1110.0, 1114.0, 1117.0, 1120.0, 1123.0, 1126.0]

# %%
price_2016df = price_df[['City Code','January 2016','February 2016','March 2016', 'April 2016','May 2016', 
          'June 2016', 'July 2016', 'August 2016','September 2016', 'October 2016', 'November 2016','December 2016']]
#price_2016df_drop= price_2016df.drop( ['City Code'], 1, inplace=True)
merge_test2= pd.merge(price_2012df, price_2016df, on= 'City Code' , how='outer') 
merge_test2
# del merge_test2['City Code']
# merge_test2T= merge_test2.T
# merge_test2T
# merge_test2T= merge_test2T.rename(columns={0:'CharlotteRent$'})
# merge_test2T
# merge_test2T['CharlotteRent$']= merge_test2T['CharlotteRent$'].map('${:.2f}'.format)
# merge_test2T
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'City Code'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-2eea1000ba1d> in <module>()
# ...

# %%
price_T16_df= price_2016df.T
print(price_T16_df)
price_T16_df = price_T16_df.rename(columns={19:'CharlotteRent_2016'})
price_T16_df
price_T12_df = price_2012df.T
price_T12_df = price_T12_df.rename(columns={19:'CharlotteRent_2012'})
price_T16_df
# Out:
#                    19
# City Code       24043
# January 2016     1252
# February 2016    1261
# March 2016       1269
# April 2016       1276
# May 2016         1283
# June 2016        1289
# July 2016        1289
# August 2016      1287
# September 2016   1285
# October 2016     1285
# November 2016    1286
# December 2016    1290
#                 CharlotteRent_2016
# City Code                    24043
# January 2016                  1252
# February 2016                 1261
# March 2016                    1269
# April 2016                    1276
# May 2016                      1283
# June 2016                     1289
# July 2016                     1289
# August 2016                   1287
# September 2016                1285
# October 2016                  1285
# November 2016                 1286
# December 2016                 1290

# %%
zip_charlotte=zip_csv.loc[zip_csv['ZipName']== 'Charlotte, NC']
zip_denver = zip_csv.loc[zip_csv['ZipName']== 'Denver, CO']
zip_charlotte
#zip_denver
# Out:
#              Month  ZipCode        ZipName Footnote  Median Listing Price  \
# 4529    2017-09-01  28202.0  Charlotte, NC      NaN              339500.0
# 4530    2017-09-01  28203.0  Charlotte, NC        *              575900.0
# 4531    2017-09-01  28204.0  Charlotte, NC      NaN              497000.0
# 4532    2017-09-01  28205.0  Charlotte, NC        *              362500.0
# 4533    2017-09-01  28206.0  Charlotte, NC      NaN              306900.0
# 4534    2017-09-01  28207.0  Charlotte, NC        *             1057300.0
# 4535    2017-09-01  28208.0  Charlotte, NC        *              139000.0
# 4536    2017-09-01  28209.0  Charlotte, NC      NaN              433000.0
# 4537    2017-09-01  28210.0  Charlotte, NC        *              412400.0
# 4538    2017-09-01  28211.0  Charlotte, NC      NaN              699500.0
# 4539    2017-09-01  28212.0  Charlotte, NC        *              167700.0
# 4540    2017-09-01  28213.0  Charlotte, NC        *              196100.0
# ...

# %%
# charlotte_zip_sort= zip_charlotte.sort_values(['Median Listing Price'], ascending=False)
# print(charlotte_zip_sort)

charlotte = zip_charlotte[['ZipCode','Month', 'Median Listing Price', 'Avg Listing Price', 'Total Listing Count']]
charlote = charlotte.to_string(columns = ['Month'])
charlote= charlotte.to_string(columns = ['ZipCode']) 

charlotte = charlotte.groupby(charlotte['ZipCode'], as_index=True)
charlotte_ALP = charlotte['Avg Listing Price'].mean()
charlotte_MLP = charlotte['Median Listing Price'].mean()
charlotte_TLC = charlotte['Total Listing Count'].mean()
charlotte_ALP= pd.DataFrame(charlotte_ALP)

charlotte_ALP['Avg Listing Price']= pd.to_numeric(charlotte_ALP['Avg Listing Price'])
charlotte_ALP.plot(kind='bar', use_index=True, title='Average Listing Price in Charlotte NC by Zipcode 2011-2017', figsize=(15,4))


x_axis = np.arange(len(charlotte_ALP))
tick_loc = [value for value in x_axis]
plt.xticks(tick_loc, rotation=45)


charlotte_ALP['Avg Listing Price']=charlotte_ALP['Avg Listing Price'].map('${:,.2f}'.format)
print(charlotte_ALP.dtypes)

plt.tight_layout()
plt.savefig('charlotte_ALP')
# Out:
# Avg Listing Price    object
# dtype: object

# %%
charlotte_MLP.plot(kind='bar', use_index=True, title='Average Median Listing Price in Charlotte NC by Zipcode 2011-2017', figsize=(15,4))
plt.tight_layout()
plt.savefig('charlotte_MLP')

# %%
charlotte_TLC.plot(kind='bar', use_index=True, title='Average Number of Total Listing by Zipcode 2011-2017', figsize=(15,4))
plt.tight_layout()
plt.savefig('charlotte_TLC')

# %%
charlotte_month1 = charlotte.loc[charlotte['Month']=='2017-09-01']
charlotte_month1
charlotte_month2 = charlotte.loc[charlotte['Month']=='2017-08-01']
charlotte_month1
charlotte_month2
merge_test = pd.merge(charlotte_month1, charlotte_month2, on='ZipCode', how='outer', suffixes=('_17-09','_17-08')) 
merge_test = merge_test.set_index(['ZipCode'])
merge_test
merge_test1 = merge_test.T
merge_test1
